# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install dcase_util>=0.2.8
! pip install keras>=2.2.2
! pip install tensorflow>=1.9.0
! pip install sed_eval>=0.2.0
! pip install pretty_midi

# %%
import tensorflow.compat.v1 as tf
import dcase_util
from dcase_util.containers import AudioContainer
import os, numpy
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import sed_eval
# %matplotlib inline
import os
import shutil # move files and delete folders with files
import tarfile
import urllib.request # download files folder
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import IPython.display as ipd
import librosa, librosa.display
import re
import IPython # listen to sounds on Python

# %%
# Handy tool to print data in HTML form
log = dcase_util.ui.FancyHTMLPrinter()

# Paths to store data
data_storage_path = '/content/data'
dataset_storage_path = os.path.join(data_storage_path, 'datasets')
feature_storage_path = os.path.join(data_storage_path, 'features_sed')
dcase_util.utils.Path().create(
    [data_storage_path, dataset_storage_path, feature_storage_path]
)

# Filename for acoustic model
model_filename = os.path.join(data_storage_path, 'model_sed.h5')  


dcase_util.keras.setup_keras(backend='tensorflow')
import keras
from keras.layers import *
from keras.models import Model

# %%
def readAudio(filename):
    x, sr = librosa.load(filename, sr=16000)
    return x, sr

#calculate spectrogram
def calc_spec(x):
    n_fft = 1024
    hop_length = 512
    win_length = 1024
    X = np.abs(librosa.stft(x, n_fft = n_fft, hop_length = hop_length, win_length = win_length, window='hann', dtype = np.complex256))
    X = librosa.power_to_db(X**2,ref=np.max)
    return X

# %%
def get_feature_matrix(audio_filename_path):  
    """Extract acoustic features (log mel-energies) for given audio file and store them."""
    
    audio, fs = librosa.load(audio_filename_path)
    hop_len = 0.02
    mel_extractor = dcase_util.features.MelExtractor(n_mels=40, win_length_seconds=0.04, hop_length_seconds=hop_len, fs = fs)
    mel_data = mel_extractor.extract(y=audio)
    #numpy.save(feature_filename, mel_data)
    return mel_data, hop_len

# %%
def get_feature_matrix_script_features(audio_filename_path):  
    """Extract acoustic features (log mel-energies) for given audio file and store them."""
    
    audio, fs = librosa.load(audio_filename_path, sr = 16000)
    mel_data = calc_spec(audio)
    # hop_len = 0.02
    # mel_extractor = dcase_util.features.MelExtractor(n_mels=40, win_length_seconds=0.04, hop_length_seconds=hop_len, fs = fs)
    # mel_data = mel_extractor.extract(y=audio)
    #numpy.save(feature_filename, mel_data)

    return mel_data, 10/mel_data.shape[1]

# %%
def csv_to_meta_container(csv_file_path):
  dict_container = dcase_util.containers.ListDictContainer(filename = csv_file_path)
  dict_container.load()
  train_meta = dcase_util.containers.MetaDataContainer(dict_container)
  print(train_meta)
  return train_meta

# %%
train_meta = csv_to_meta_container('/content/drive/MyDrive/Ee603_mlsp/Project/dataset_updated/labels_updated.csv')
# Out:
# MetaDataContainer :: Class
# Items                               : 2160
# Unique
#   Files                             : 1020
#   Scene labels                      : 0
#   Event labels                      : 2
#   Tags                              : 0
#   Identifiers                       : 0
#   Source labels                     : 0
#
# Meta data
#   Source                  Onset   Offset   Scene             Event             Tags              Identifier
#   --------------------   ------   ------   ---------------   ---------------   ---------------   -----
#   S991                     5.00    10.00   -                 music             -                 -
#   S992                     5.00    10.00   -                 music             -                 -
#   S993                     5.00    10.00   -                 music             -                 -
#   S994                     5.00    10.00   -                 music             -                 -
#   S995                     5.00    10.00   -                 music             -                 -
#   S996                     5.00    10.00   -                 music             -                 -
#   S997                     5.00    10.00   -                 music             -                 -
#   S998                     5.00    10.00   -                 music             -                 -
#   S999                     5.00    10.00   -                 music             -                 -
#   S1000                    5.00    10.00   -                 music             -                 -
#   S1001                    5.00    10.00   -                 music             -                 -
#   S1002                    5.00    10.00   -                 music             -                 -
#   S1003                    5.00    10.00   -                 music             -                 -
#   S1004                    5.00    10.00   -                 music             -                 -
#   S1005                    5.00    10.00   -                 music             -                 -
#   S1006                    5.00    10.00   -                 music             -                 -
#   S1007                    5.00    10.00   -                 music             -                 -
#   S1008                    5.00    10.00   -                 music             -                 -
#   S1009                    5.00    10.00   -                 music             -                 -
#   S1010                    5.00    10.00   -                 music             -                 -
#   S1011                    5.00    10.00   -                 music             -                 -
#   S1012                    5.00    10.00   -                 music             -                 -
#   S1013                    5.00    10.00   -                 music             -                 -
#   S1014                    5.00    10.00   -                 music             -                 -
#   S1015                    5.00    10.00   -                 music             -                 -
#   S1016                    5.00    10.00   -                 music             -                 -
#   S1017                    5.00    10.00   -                 music             -                 -
#   S1018                    5.00    10.00   -                 music             -                 -
#   S1019                    5.00    10.00   -                 music             -                 -
#   S1020                    5.00    10.00   -                 music             -                 -
#
# Event statistics
#   Event label             Count   Tot. Length   Avg. Length
#   --------------------   ------   -----------   -----------
#   music                    1020       2850.00          2.79
#   speech                   1140       3150.00          2.76

# %%
X_train_ = []
Y_train_ = []
audio_folder_name = '/content/drive/MyDrive/Ee603_mlsp/Project/dataset_updated/wav_updated'
for audio_filename in os.listdir(audio_folder_name):#os.listdir() s1.wav, s2.wav
    #print('Load', db.absolute_to_relative_path(audio_filename))
    
    # Extract features, load them from file if they exists, if not extract and save
    audio_path = os.path.join(audio_folder_name, audio_filename)
    features, hop_length_seconds = get_feature_matrix_script_features(audio_path)
   
    # Targets
    event_list = train_meta.filter(filename=audio_filename.split('.')[0])
    event_roll = event_list.to_event_roll(
        label_list = ['speech', 'music'],                                       # Event labels
        time_resolution = hop_length_seconds,                   # Time resolution of feature matrix
        length_seconds = features.shape[1] * hop_length_seconds   # Length of original audio signal
    ).data

    event_roll = np.array(event_roll)
    silence_roll = np.zeros((1, event_roll.shape[1]))
    for index_ in range(event_roll.shape[1]):
      if(event_roll[0][index_] < 0.5 and event_roll[1][index_] < 0.5):
        silence_roll[0][index_] = 1


    #stack silence roll
    event_roll = np.concatenate((event_roll,silence_roll), axis = 0)

    X_train_.append(features) 
    Y_train_.append(event_roll)

# %%
# X_train_ = np.stack(X_train_)
# Y_train_ = np.stack(Y_train_)
Y_train_ = np.moveaxis(Y_train_, 1, 2)
print('----------------------')
print('X_train shape', X_train_.shape)
print('Y_train shape', Y_train_.shape)
# Out:
# ----------------------
# X_train shape (1008, 513, 313)
# Y_train shape (1008, 313, 3)

# %%
X_train = np.moveaxis(X_train_, 1, 2)
X_train = X_train.reshape(-1, X_train.shape[-1])
Y_train = Y_train_.reshape(-1, Y_train_.shape[-1])
print('X_train shape', X_train.shape)
print('Y_train shape', Y_train.shape)
# Out:
# X_train shape (315504, 513)
# Y_train shape (315504, 3)

# %%
music_count=0
speech_count=0
silence_count=0

for i in range(Y_train_.shape[0]):
  if(Y_train_[i][0][0]==1):
    speech_count = speech_count+1
  elif(Y_train_[i][0][1]==1):
    music_count = music_count+1
  else:
    silence_count = silence_count+1

total_count = Y_train_.shape[0]
music_prob = float(music_count)/total_count
speech_prob = float(speech_count)/total_count
silence_prob = float(silence_count)/total_count

initial_state_probs = pd.Series([music_prob,speech_prob,silence_prob], index=['music', 'speech','silence'])
display(initial_state_probs)
# Out:
# music      0.236111
# speech     0.380952
# silence    0.382937
# dtype: float64

# %%
def normalize(a, axis=None):
    """
    Normalize the input array so that it sums to 1.
    Parameters
    ----------
    a : array
        Non-normalized input data.
    axis : int
        Dimension along which normalization is performed.
    Notes
    -----
    Modifies the input **inplace**.
    """
    a_sum = a.sum(axis)
    if axis and a.ndim > 1:
        # Make sure we don't divide by zero.
        a_sum[a_sum == 0] = 1
        shape = list(a.shape)
        shape[axis] = 1
        a_sum.shape = shape

    a /= a_sum

# %%
def log_normalize(a, axis=None):
    """
    Normalize the input array so that ``sum(exp(a)) == 1``.
    Parameters
    ----------
    a : array
        Non-normalized input data.
    axis : int
        Dimension along which normalization is performed.
    Notes
    -----
    Modifies the input **inplace**.
    """
    if axis is not None and a.shape[axis] == 1:
        # Handle single-state GMMHMM in the degenerate case normalizing a
        # single -inf to zero.
        a[:] = 0
    else:
        with np.errstate(under="ignore"):
            a_lse = special.logsumexp(a, axis, keepdims=True)
        a -= a_lse

# %%
def iter_from_X_lengths(X, lengths):
    warnings.warn(
        "iter_from_X_lengths is deprecated and will be removed in the future.",
        DeprecationWarning, stacklevel=2)
    if lengths is None:
        yield 0, len(X)
    else:
        n_samples = X.shape[0]
        end = np.cumsum(lengths).astype(np.int32)
        start = end - lengths
        if end[-1] > n_samples:
            raise ValueError("more than {:d} samples in lengths array {!s}"
                             .format(n_samples, lengths))

        for i in range(len(lengths)):
            yield start[i], end[i]

# %%
def log_mask_zero(a):
    """
    Compute the log of input probabilities masking divide by zero in log.
    Notes
    -----
    During the M-step of EM-algorithm, very small intermediate start
    or transition probabilities could be normalized to zero, causing a
    *RuntimeWarning: divide by zero encountered in log*.
    This function masks this unharmful warning.
    """
    a = np.asarray(a)
    with np.errstate(divide="ignore"):
        return np.log(a)


def fill_covars(covars, , n_components=1, n_features=1):
  return covars

# %% [markdown]
# Multivariate Normal Distribution Function

# %%
def _log_multivariate_normal_density(X, means, covars, min_covar=1.e-7):
    """Log probability for full covariance matrices."""
    n_samples, n_dim = X.shape
    nmix = len(means)
    log_prob = np.empty((n_samples, nmix))
    for c, (mu, cv) in enumerate(zip(means, covars)):
        try:
            cv_chol = linalg.cholesky(cv, lower=True)
        except linalg.LinAlgError:
            # The model is most probably stuck in a component with too
            # few observations, we need to reinitialize this components
            try:
                cv_chol = linalg.cholesky(cv + min_covar * np.eye(n_dim),lower=True)
            except linalg.LinAlgError:
                raise ValueError("'covars' must be symmetric, ""positive-definite")

        cv_log_det = 2 * np.sum(np.log(np.diagonal(cv_chol)))
        cv_sol = linalg.solve_triangular(cv_chol, (X - mu).T, lower=True).T
        log_prob[:, c] = - .5 * (np.sum(cv_sol ** 2, axis=1) +  n_dim * np.log(2 * np.pi) + cv_log_det)

    return log_prob

# %% [markdown]
# Viterbi Algorithm

# %%
def _viterbi(int n_samples, int n_components,
             dtype_t[:] log_startprob,
             dtype_t[:, :] log_transmat,
             dtype_t[:, :] framelogprob):

    cdef int i, j, t, where_from
    cdef dtype_t logprob

    cdef int[::view.contiguous] state_sequence = \
        np.empty(n_samples, dtype=np.int32)
    cdef dtype_t[:, ::view.contiguous] viterbi_lattice = \
        np.zeros((n_samples, n_components))
    cdef dtype_t[::view.contiguous] work_buffer = np.empty(n_components)

    with nogil:
        for i in range(n_components):
            viterbi_lattice[0, i] = log_startprob[i] + framelogprob[0, i]

        # Induction
        for t in range(1, n_samples):
            for i in range(n_components):
                for j in range(n_components):
                    work_buffer[j] = (log_transmat[j, i]
                                      + viterbi_lattice[t - 1, j])

                viterbi_lattice[t, i] = _max(work_buffer) + framelogprob[t, i]

        # Observation traceback
        state_sequence[n_samples - 1] = where_from = \
            _argmax(viterbi_lattice[n_samples - 1])
        logprob = viterbi_lattice[n_samples - 1, where_from]

        for t in range(n_samples - 2, -1, -1):
            for i in range(n_components):
                work_buffer[i] = (viterbi_lattice[t, i]+ log_transmat[i, where_from])

            state_sequence[t] = where_from = _argmax(work_buffer)

    return np.asarray(state_sequence), logprob

# %%
class _HMM():
    """
    Base class for Hidden Markov Models.

    startprob_ : array, shape (n_components, )
        Initial state occupation distribution.
    transmat_ : array, shape (n_components, n_components)
        Matrix of transition probabilities between states.
    """

    def __init__(self, n_components=1,):
        """
        Parameters
        ----------
        n_components : int
            Number of states in the model.
        """
        self.n_components = n_components

    def get_stationary_distribution(self):
        """Compute the stationary distribution of states."""
        # The stationary distribution is proportional to the left-eigenvector
        # associated with the largest eigenvalue (i.e., 1) of the transition
        # matrix.
        check_is_fitted(self, "transmat_")
        eigvals, eigvecs = linalg.eig(self.transmat_.T)
        eigvec = np.real_if_close(eigvecs[:, np.argmax(eigvals)])
        return eigvec / eigvec.sum()

    def score_samples(self, X, lengths=None):
       """
         Compute the log probability under the model and compute posteriors.
        """
        return self._score(X, lengths, compute_posteriors=True)

    def score(self, X, lengths=None):
        """
        Compute the log probability under the model.
        Parameters
        ----------
      
        """
        return self._score(X, lengths, compute_posteriors=False)[0]

    def _score(self, X, lengths=None, *, compute_posteriors):
        """
        Helper for `score` and `score_samples`.
        Compute the log probability under the model, as well as posteriors if
        *compute_posteriors* is True (otherwise, an empty array is returned
        for the latter).
        """
        check_is_fitted(self, "startprob_")
        self._check()

        X = check_array(X)
        impl = {
            "scaling": self._score_scaling,
            "log": self._score_log,
        }[self.implementation]
        return impl(X=X, lengths=lengths, compute_posteriors=compute_posteriors)

    def _score_log(self, X, lengths=None, *, compute_posteriors):
        """
        Compute the log probability under the model, as well as posteriors if
        *compute_posteriors* is True (otherwise, an empty array is returned
        for the latter).
        """
        logprob = 0
        sub_posteriors = [np.empty((0, self.n_components))]
        for sub_X in split_X_lengths(X, lengths):
            framelogprob = self._compute_log_likelihood(sub_X)
            logprobij, fwdlattice = self._do_forward_log_pass(framelogprob)
            logprob += logprobij
            if compute_posteriors:
                bwdlattice = self._do_backward_log_pass(framelogprob)
                sub_posteriors.append(
                    self._compute_posteriors_log(fwdlattice, bwdlattice))
        return logprob, np.concatenate(sub_posteriors)

    def _score_scaling(self, X, lengths=None, *, compute_posteriors):
        logprob = 0
        sub_posteriors = [np.empty((0, self.n_components))]
        for sub_X in split_X_lengths(X, lengths):
            frameprob = self._compute_likelihood(sub_X)
            logprobij, fwdlattice, scaling_factors = \
                    self._do_forward_scaling_pass(frameprob)
            logprob += logprobij
            if compute_posteriors:
                bwdlattice = self._do_backward_scaling_pass(
                    frameprob, scaling_factors)
                sub_posteriors.append(
                    self._compute_posteriors_scaling(fwdlattice, bwdlattice))

        return logprob, np.concatenate(sub_posteriors)

    def _decode_viterbi(self, X):
        framelogprob = self._compute_log_likelihood(X)
        return self._do_viterbi_pass(framelogprob)

    def _decode_map(self, X):
        _, posteriors = self.score_samples(X)
        logprob = np.max(posteriors, axis=1).sum()
        state_sequence = np.argmax(posteriors, axis=1)
        return logprob, state_sequence

    def decode(self, X, lengths=None):
        """
          Find most likely state sequence corresponding to ``X``.
        """
        check_is_fitted(self, "startprob_")
        self._check()

        algorithm = algorithm or self.algorithm
        if algorithm not in DECODER_ALGORITHMS:
            raise ValueError("Unknown decoder {!r}".format(algorithm))

        decoder = {
            "viterbi": self._decode_viterbi,
            "map": self._decode_map
        }[algorithm]

        X = check_array(X)
        logprob = 0
        sub_state_sequences = []
        for sub_X in split_X_lengths(X, lengths):
            # XXX decoder works on a single sample at a time!
            sub_logprob, sub_state_sequence = decoder(sub_X)
            logprob += sub_logprob
            sub_state_sequences.append(sub_state_sequence)

        return logprob, np.concatenate(sub_state_sequences)

    def predict(self, X, lengths=None):
        """
        Find most likely state sequence corresponding to ``X``.
        Parameters
        ----------
        X : array-like, shape (n_samples, n_features)
            Feature matrix of individual samples.
        lengths : array-like of integers, shape (n_sequences, ), optional
            Lengths of the individual sequences in ``X``. The sum of
            these should be ``n_samples``.
        Returns
        -------
        state_sequence : array, shape (n_samples, )
            Labels for each sample from ``X``.
        """
        _, state_sequence = self.decode(X, lengths)
        return state_sequence

    def predict_proba(self, X, lengths=None):
        """
        Compute the posterior probability for each state in the model.
        Parameters
        ----------
        X : array-like, shape (n_samples, n_features)
            Feature matrix of individual samples.
        lengths : array-like of integers, shape (n_sequences, ), optional
            Lengths of the individual sequences in ``X``. The sum of
            these should be ``n_samples``.
        Returns
        -------
        posteriors : array, shape (n_samples, n_components)
            State-membership probabilities for each sample from ``X``.
        """
        _, posteriors = self.score_samples(X, lengths)
        return posteriors 


    def _do_viterbi_pass(self, framelogprob):
        n_samples, n_components = framelogprob.shape
        state_sequence, logprob = _viterbi(
            n_samples, n_components, log_mask_zero(self.startprob_),
            log_mask_zero(self.transmat_), framelogprob)
        return logprob, state_sequence

# %%
class GMMM_HMM(_HMM):
    """
    Hidden Markov Model with Gaussian emissions.
    Attributes
    ----------
    n_features : int
        Dimensionality of the Gaussian emissions.
    monitor_ : ConvergenceMonitor
        Monitor object used to check the convergence of EM.
    startprob_ : array, shape (n_components, )
        Initial state occupation distribution.
    transmat_ : array, shape (n_components, n_components)
        Matrix of transition probabilities between states.
    means_ : array, shape (n_components, n_features)
        Mean parameters for each state.
    covars_ : array
        Covariance parameters for each state.
    """

    def __init__(self, n_components=1,
                 min_covar=1e-3,
                 startprob_prior=1.0, transmat_prior=1.0,
                 means_prior=0, means_weight=0,
                 covars_prior=1e-2, covars_weight=1,
                 algorithm="viterbi", random_state=None,
                 n_iter=10, tol=1e-2, verbose=False,
                 params="stmc", init_params="stmc",
                 implementation="log"):
        """
        Parameters
        ----------
        n_components : int
            Number of states.
        """
        _HMM.__init__(self, n_components)
        

    @property
    def covars_(self):
        """Return covars as a full matrix."""
        return fill_covars(self._covars_,
                           self.n_components, self.n_features)

    @covars_.setter
    def covars_(self, covars):
        covars = np.array(covars, copy=True)
        _validate_covars(covars,self.n_components)
        self._covars_ = covars

    def _get_n_fit_scalars_per_param(self):
        nc = self.n_components
        nf = self.n_features
        return {
            "s": nc - 1,
            "t": nc * (nc - 1),
            "m": nc * nf,
            "c": {
                "spherical": nc,
                "diag": nc * nf,
                "full": nc * nf * (nf + 1) // 2,
                "tied": nf * (nf + 1) // 2,
            }[self.covariance_type],
        }

    def _init(self, X, lengths=None):
        _check_and_set_gaussian_n_features(self, X)
        super()._init(X, lengths=lengths)

        if self._needs_init("m", "means_"):
            kmeans = cluster.KMeans(n_clusters=self.n_components,
                                    random_state=self.random_state)
            kmeans.fit(X)
            self.means_ = kmeans.cluster_centers_
        if self._needs_init("c", "covars_"):
            cv = np.cov(X.T) + self.min_covar * np.eye(X.shape[1])
            if not cv.shape:
                cv.shape = (1, 1)
            self.covars_ = \
                distribute_covar_matrix_to_match_covariance_type(
                    cv, self.n_components).copy()

    def _check(self):
        super()._check()

        self.means_ = np.asarray(self.means_)
        self.n_features = self.means_.shape[1]

        if self.covariance_type not in COVARIANCE_TYPES:
            raise ValueError('covariance_type must be one of {}'
                             .format(COVARIANCE_TYPES))

    def _compute_log_likelihood(self, X):
        return log_multivariate_normal_density(
            X, self.means_, self._covars_)

    def _generate_sample_from_state(self, state, random_state=None):
        random_state = check_random_state(random_state)
        return random_state.multivariate_normal(
            self.means_[state], self.covars_[state]
        )

    def _initialize_sufficient_statistics(self):
        stats = super()._initialize_sufficient_statistics()
        stats['post'] = np.zeros(self.n_components)
        stats['obs'] = np.zeros((self.n_components, self.n_features))
        stats['obs**2'] = np.zeros((self.n_components, self.n_features))
        if self.covariance_type in ('tied', 'full'):
            stats['obs*obs.T'] = np.zeros((self.n_components, self.n_features,
                                           self.n_features))
        return stats

    def _accumulate_sufficient_statistics(self, stats, obs, lattice,
                                          posteriors, fwdlattice, bwdlattice):
        super()._accumulate_sufficient_statistics(
            stats, obs, lattice, posteriors, fwdlattice, bwdlattice)

        if 'm' in self.params or 'c' in self.params:
            stats['post'] += posteriors.sum(axis=0)
            stats['obs'] += np.dot(posteriors.T, obs)

        if 'c' in self.params:
            if self.covariance_type in ('spherical', 'diag'):
                stats['obs**2'] += np.dot(posteriors.T, obs ** 2)
            elif self.covariance_type in ('tied', 'full'):
                # posteriors: (nt, nc); obs: (nt, nf); obs: (nt, nf)
                # -> (nc, nf, nf)
                stats['obs*obs.T'] += np.einsum(
                    'ij,ik,il->jkl', posteriors, obs, obs)

    def _do_mstep(self, stats):
        super()._do_mstep(stats)

        means_prior = self.means_prior
        means_weight = self.means_weight

       
        denom = stats['post'][:, None]
        if 'm' in self.params:
            self.means_ = ((means_weight * means_prior + stats['obs'])
                           / (means_weight + denom))

        if 'c' in self.params:
            covars_prior = self.covars_prior
            covars_weight = self.covars_weight
            meandiff = self.means_ - means_prior

              c_n = np.empty((self.n_components, self.n_features,
                              self.n_features))
              for c in range(self.n_components):
                  obsmean = np.outer(stats['obs'][c], self.means_[c])
                  c_n[c] = (means_weight * np.outer(meandiff[c],
                                                    meandiff[c])
                            + stats['obs*obs.T'][c]
                            - obsmean - obsmean.T
                            + np.outer(self.means_[c], self.means_[c])
                            * stats['post'][c])
              cvweight = max(covars_weight - self.n_features, 0)

# %% [markdown]
# Make utility functions for feature extraction, calculation of matrices and post processing

# %%
COL_NAMES_FEATURES = []
for i in range(0,513):  #column headers
  COL_NAMES_FEATURES.append(str(i)+"c")
def __calc_prob_class(class_group):
    class_group_count = class_group.groupby('sequence_class').size().reset_index()
    class_group_count.columns = ['sequence_class', 'count']
    total = class_group_count['count'].sum()
    class_group_count['transition_prob'] = class_group_count['count']/total
    return class_group_count

# %% [markdown]
# Calulation of state transition probability matrix

# %%
def calc_transition_prob_matrix(classes_annotation, test_version=False):
    initial_classes = classes_annotation['class'].values[:-1]
    sequence_class = classes_annotation['class'][1:].tolist()

    sequence_classes = pd.DataFrame({'initial_classes': initial_classes, 'sequence_class': sequence_class})
    prob_matrix = sequence_classes.groupby('initial_classes').apply(__calc_prob_class).reset_index().drop('level_1', axis=1)
    prob_matrix = prob_matrix.pivot(index='initial_classes', columns='sequence_class', values='transition_prob')
    prob_matrix.append(pd.Series(np.zeros(prob_matrix.shape[1]), name='<END>'))
    prob_matrix = prob_matrix.fillna(0)
    if(test_version == False):
        prob_matrix['<START>'] = 0.
        prob_matrix.loc['<END>'] = 0.
        prob_matrix.loc['<END>', '<END>'] = 1
    return prob_matrix

# %% [markdown]
# Calculate mean vector of GMM

# %%
def __get_mu_array(note_feature_vector):
    return note_feature_vector[COL_NAMES_FEATURES].mean()

# %% [markdown]
# Calculate state covariance matrix

# %%
def get_mu_sigma_from_spectro(spectrogram):
    mu_array = spectrogram.groupby('class').apply(__get_mu_array)

    states_cov_matrices = []
    for name, group in spectrogram.groupby('class'): # alphabetic order
        states_cov_matrices.append(group[COL_NAMES_FEATURES].cov().values)
    states_cov_matrices = np.array(states_cov_matrices)

    return [mu_array, states_cov_matrices]

# %%
def get_hmm_predictions(class_ix_predictions, ix_2_class):
    return np.array([ix_2_class[class_ix] for class_ix in class_ix_predictions])

# %% [markdown]
# Functions for simplification of labels

# %%
def __simplify_classes(classes_df):
    classes_processed = classes_df['class'].str.split(':maj')                         # remove major x classes return array of array
    classes_processed = [elem[0] for elem in classes_processed]                       # further process step above to return 1 array
    classes_processed = [elem.split('/')[0] for elem in classes_processed]            # remove inverted classes
    classes_processed = [elem.split('aug')[0] for elem in classes_processed]          # remove augmented classes
    classes_processed = [elem.split(':(')[0] for elem in classes_processed]           # remove added notes classes
    classes_processed = [elem.split('(')[0] for elem in classes_processed]            # remove added notes classes 2
    classes_processed = [elem.split(':sus')[0] for elem in classes_processed]         # remove sustained classes
    classes_processed = [re.split(":?\d", elem)[0] for elem in classes_processed]     # remove added note
    classes_processed = [elem.replace('dim', 'min') for elem in classes_processed]    # change diminute to minor
    classes_processed = [elem.replace('hmin', 'min') for elem in classes_processed]   # change semi-diminute to minor
    classes_processed = [re.split(":$", elem)[0] for elem in classes_processed]       # remove added notes classes
    return classes_processed

# %%
def read_simplify_class_file(music_file_path, process_silence=False):
    classes_annotation = pd.read_csv(music_file_path, sep=" ", header=None)
    classes_annotation.columns = ['start', 'end', 'class']
    classes_annotation['class'] = __simplify_classes(classes_annotation)
    if(process_silence == True): # replace silence by probable tonal end
        classes_annotation.loc[classes_annotation['class'] == 'N', 'class'] = classes_annotation['class'].mode()[0]
    return classes_annotation

# %%
def simplify_predicted_classes(spectrogram, predicted_col='predicted'):
    change_class = spectrogram[predicted_col] != spectrogram[predicted_col].shift(-1)
    change_class_ix = change_class[change_class == True].index
    filtered_pcp = spectrogram.loc[change_class_ix].copy()
    end_time_previous = np.array([0] + filtered_pcp['end'][:-1].tolist())
    filtered_pcp['start'] = end_time_previous
    return filtered_pcp[[predicted_col, 'start', 'end']].reset_index(drop=True)

# %% [markdown]
# #Spectrogram Feature Extraction

# %%
def calc_spectrogram(x, Fs, plot=True):
    """ Calculates the spectrogram features of the audio file and outputs a numpy matrix of shape"""
    n_fft = 1024
    hop_length = 512
    win_length = 1024
    C = np.abs(librosa.stft(x, n_fft = n_fft, hop_length = hop_length, win_length = win_length, window='hann', dtype = np.complex256))
    C = librosa.power_to_db(C**2,ref=np.max)

    if(plot==True):
        plt.figure(figsize=(12, 3))
        plt.title('spectrogram $\mathcal{C}$')
        librosa.display.specshow(C, x_axis='time', y_axis='spectro', cmap='gray_r', hop_length=1024)
        plt.xlabel('Time (frames)'); plt.ylabel('spectro')
        plt.colorbar(); plt.clim([0, 1])
        plt.tight_layout()
    return C

# %%
def get_frame_stats(spectrogram, signal, Fs):
    frames_per_sec = spectrogram.shape[1]/(len(signal)/Fs) # Nbr of frames / length in seconds = frames per second
    frame_duration_sec = 1/frames_per_sec        # frame duration = 1 / frames per second
    return [frames_per_sec, frame_duration_sec]

# %% [markdown]
# Convert numpy spectrogram matrix to Pandas dataframe

# %%
def spectrogram_2_dataframe(spectrogram, frame_duration_sec, test_version=False):
    spectrogram = pd.DataFrame(np.transpose(spectrogram), columns=COL_NAMES_FEATURES)

    spectrogram['start'] = np.arange(spectrogram.shape[0]) * frame_duration_sec
    spectrogram['end'] = spectrogram['start'] + frame_duration_sec

    if(test_version == False):

        start_spectrogram = pd.DataFrame(np.random.normal(loc=0, scale=0.01, size=spectrogram.shape[1]),
                                        index=spectrogram.columns).transpose()
        start_spectrogram.iloc[:,-2:] = 0                                
        end_spectrogram = pd.DataFrame(np.random.normal(loc=-1, scale=0.01, size=spectrogram.shape[1]),
                                      index=spectrogram.columns).transpose()
        end_spectrogram.iloc[:,-2:] = spectrogram.iloc[-1]['end']+.01
        spectrogram = start_spectrogram.append(spectrogram, ignore_index=True).append(end_spectrogram, ignore_index=True)

    return spectrogram

# %%
def __get_class_ix(elem, classes_annotation):
    diffs = classes_annotation['start'] - elem
    return diffs[diffs <= 0].index[-1]

# %%
def smooth_classes_by_beat(spectrogram, signal, sr, predicted_col='predicted', n_beats=1):
    _, beats = librosa.beat.beat_track(y=signal, sr=sr)
    beat_times = librosa.frames_to_time(beats, sr=sr)
    beat_times = beat_times * 2 * n_beats
    beat_times[0] = 0
    pcp = spectrogram[['end', predicted_col]].copy()
    pcp['class_cluster'] = np.digitize(pcp['end'], beat_times)
    mode_cluster = pcp.groupby('class_cluster')[predicted_col].agg(lambda x:x.value_counts().index[0])
    pcp['predicted_cluster'] = mode_cluster.loc[pcp['class_cluster']].values
    return pcp['predicted_cluster']

# %% [markdown]
# Function for instantiate an object of GMM_HMM class

# %%
def build_gaussian_hmm(initial_state_prob, transition_matrix, mu_array, states_cov_matrices):
    # continuous emission model
    h_markov_model = GMM_HMM(n_components=transition_matrix.shape[0])
    # initial state probability
    h_markov_model.startprob_ = initial_state_prob
    # transition matrix probability
    h_markov_model.transmat_ = transition_matrix.values

    # part of continuous emission probability - multidimensional gaussian
    # mean vector of shape [n_states, n_features]
    h_markov_model.means_ = mu_array
    # array of covariance of shape [n_states, n_features, n_features]
    h_markov_model.covars_ = states_cov_matrices
    return h_markov_model

# %% [markdown]
# Calculation of different HMM matrices

# %%
def calc_hmm_matrices(spectrogram, process_silence=True, test_version=False):
    """ Calculates the matrices of a HMM model"""
    # Transition Matrix
    transition_matrix2 = calc_transition_prob_matrix(spectrogram, test_version=test_version)
    # mu and covariance matrices
    mu_array2, states_cov_matrices2 = get_mu_sigma_from_spectro(spectrogram)
    # return filtered_initial_states2, transition_matrix2, mu_array2, states_cov_matrices2
    return  transition_matrix2, mu_array2, states_cov_matrices2

# %% [markdown]
# Predictions of HMM model

# %%
def get_predictions(h_markov_model, prediction_dict, song_path, test_version=False):
    # get predictions
    signal, sr, spectrogram = build_spectro(song_path, process_silence=True, test_version=False)
    class_ix_predictions2 = h_markov_model.predict(spectrogram[COL_NAMES_FEATURES])

    spectrogram['predicted'] = get_hmm_predictions(class_ix_predictions2, prediction_dict)
    spectrogram['predicted_cluster'] = smooth_classes_by_beat(spectrogram, signal, sr, predicted_col='predicted', n_beats=1)
    return spectrogram

# %% [markdown]
# Convert Numpy matrices of training data to Pandas dataframes

# %%
X_train_df = pd.DataFrame(data = X_train, columns = COL_NAMES_FEATURES )
labels = []
for i in range(Y_train.shape[0]):
  if (Y_train[i][0]==1):
    labels.append('speech')
  elif (Y_train[i][1]==1):
    labels.append('music')
  else:
    labels.append('silence')
    

label = np.array(labels)
Y_train_df = pd.DataFrame(data = label, columns = ['class'] )
final_input = pd.concat([X_train_df, Y_train_df], axis=1, join="inner")  #concatenating the feature df and the labels df
final_input.shape
# Out:
# (315504, 514)

# %% [markdown]
# Calculate State, Transition Matrix, Means and Covariance Matrix

# %%
transition_matrix, mu_array, states_cov_matrices = calc_hmm_matrices(final_input, test_version=False)
ix_2_class = {ix_: class_str for ix_,class_str in zip(range(len(mu_array.index.values)),mu_array.index.values)}

# %%
transition_matrix =  transition_matrix.drop(["<START>", "<END>"], axis = 1, inplace = False)
transition_matrix =  transition_matrix.drop([ "<END>"], axis = 0, inplace = False)

# %%
transition_matrix
# Out:
# sequence_class      music   silence    speech
# initial_classes
# music            0.989450  0.005048  0.005502
# silence          0.003833  0.992683  0.003484
# speech           0.004420  0.005092  0.990489

# %% [markdown]
# Dimensions of Means and Covariance Matrices

# %%
print(mu_array.shape)
print(states_cov_matrices.shape)
# Out:
# (3, 513)
# (3, 513, 513)

# %% [markdown]
# Make a Gaussian HMM Model with the previously calculated matrices

# %%
h_markov_model = build_gaussian_hmm(initial_state_probs,transition_matrix,  mu_array, states_cov_matrices)

# %% [markdown]
# ## Predict

# %% [markdown]
# Predictions on the validation set
#
# Validation set contains 170 audio files of 10s each

# %%
output = pd.DataFrame()
validation_folder_name = '/content/drive/MyDrive/Ee603_mlsp/Project/validation'
for audio_filename in os.listdir(validation_folder_name):
  filename = '/content/drive/MyDrive/Ee603_mlsp/Project/validation/'+audio_filename
  x, Fs = librosa.load(filename,sr=16000)
  spectrogram_features = calc_spectrogram(x, Fs, plot=False)
  
  class_ix_predictions2 = h_markov_model.predict(np.moveaxis(spectrogram_features,0,1))
  state_predictions = get_hmm_predictions(class_ix_predictions2, ix_2_class)

  frames_per_sec, frame_duration_sec = get_frame_stats(spectrogram=spectrogram_features, signal=x, Fs=Fs)
  features_df = spectrogram_2_dataframe(spectrogram_features, frame_duration_sec, test_version=True)
  features_df['predicted'] = state_predictions
  classes_simplified = simplify_predicted_classes(features_df)
  classes_simplified['filename'] = audio_filename
  output = pd.concat([output, classes_simplified], axis=0, join="outer")

output = output[['filename', 'start', 'end', 'predicted']]   #reordering the columns
output.to_csv('task1.csv')  #save the output as csv file

# %% [markdown]
# Save Model Matrices

# %%
np.save('/content/drive/MyDrive/Ee603_mlsp/Project/hmm_matrices/transition_matrix.npy',transition_matrix)
np.save('/content/drive/MyDrive/Ee603_mlsp/Project/hmm_matrices/ispm.npy', initial_state_probs)
np.save('/content/drive/MyDrive/Ee603_mlsp/Project/hmm_matrices/mu_array.npy', mu_array)
np.save('/content/drive/MyDrive/Ee603_mlsp/Project/hmm_matrices/states_cov_matrices.npy', states_cov_matrices)

# %% [markdown]
# #Evaluation

# %%
train_meta = csv_to_meta_container('/content/results_1.csv')
# Out:
# MetaDataContainer :: Class
# Items                               : 1888
# Unique
#   Files                             : 170
#   Scene labels                      : 0
#   Event labels                      : 3
#   Tags                              : 0
#   Identifiers                       : 0
#   Source labels                     : 0
#
# Meta data
#   Source                  Onset   Offset   Scene             Event             Tags              Identifier
#   --------------------   ------   ------   ---------------   ---------------   ---------------   -----
#   S28.wav                  0.00     1.53   -                 music             -                 -
#   S28.wav                  1.53     1.57   -                 speech            -                 -
#   S28.wav                  1.57     4.98   -                 music             -                 -
#   S28.wav                  4.98     8.47   -                 speech            -                 -
#   S28.wav                  8.47     8.50   -                 music             -                 -
#   S28.wav                  8.50     8.79   -                 speech            -                 -
#   S28.wav                  8.79     8.85   -                 music             -                 -
#   S28.wav                  8.85    10.00   -                 speech            -                 -
#   S30.wav                  0.00     0.03   -                 speech            -                 -
#   S30.wav                  0.03     2.72   -                 music             -                 -
#   S30.wav                  2.72     2.75   -                 speech            -                 -
#   S30.wav                  2.75     2.88   -                 music             -                 -
#   S30.wav                  2.88     2.91   -                 speech            -                 -
#   S30.wav                  2.91     4.25   -                 music             -                 -
#   S30.wav                  4.25     4.28   -                 speech            -                 -
#   S30.wav                  4.28     5.02   -                 music             -                 -
#   S30.wav                  5.02     6.26   -                 speech            -                 -
#   S30.wav                  6.26     6.29   -                 music             -                 -
#   S30.wav                  6.29     7.99   -                 speech            -                 -
#   S30.wav                  7.99     8.08   -                 music             -                 -
#   S30.wav                  8.08     8.53   -                 speech            -                 -
#   S30.wav                  8.53     8.63   -                 music             -                 -
#   S30.wav                  8.63     8.88   -                 speech            -                 -
#   S30.wav                  8.88     8.91   -                 music             -                 -
#   S30.wav                  8.91    10.00   -                 speech            -                 -
#   S29.wav                  0.00     5.02   -                 music             -                 -
#   S29.wav                  5.02     5.53   -                 speech            -                 -
#   S29.wav                  5.53     5.59   -                 music             -                 -
#   S29.wav                  5.59     7.80   -                 speech            -                 -
#   S29.wav                  7.80     7.89   -                 music             -                 -
#   S29.wav                  7.89     8.50   -                 speech            -                 -
#   S29.wav                  8.50     8.53   -                 music             -                 -
#   S29.wav                  8.53    10.00   -                 speech            -                 -
#   S27.wav                  0.00     0.61   -                 music             -                 -
#   S27.wav                  0.61     0.64   -                 speech            -                 -
#   S27.wav                  0.64     0.93   -                 music             -                 -
#   S27.wav                  0.93     0.99   -                 speech            -                 -
#   S27.wav                  0.99     1.12   -                 music             -                 -
#   S27.wav                  1.12     1.15   -                 speech            -                 -
#   S27.wav                  1.15     1.44   -                 music             -                 -
#   music                     797        478.18          0.60
#   silence                   211        679.45          3.22
#   speech                    880        542.36          0.62

# %%
res = dcase_util.containers.MetaDataContainer(filename=os.path.join(data_storage_path, 'results_sed_hmm.csv'))
for file_name in train_meta.unique_files:
  event_list = train_meta.filter(filename=file_name)
  event_list = event_list.process_events(minimum_event_gap = 0.5)
  event_list = event_list.process_events(minimum_event_length = 0.7)
  print(file_name)
  res += event_list

res = res.filter(event_list = ['speech', 'music'])

res.save('validation_results.csv')
# res.save('temp.csv')
# Out:
# S1016.wav
# S1017.wav
# S1018.wav
# S1019.wav
# S1020.wav
# S116.wav
# S117.wav
# S118.wav
# S119.wav
# S120.wav
# S146.wav
# S147.wav
# S148.wav
# S149.wav
# S150.wav
# S176.wav
# S177.wav
# S178.wav
# S179.wav
# S180.wav
# S206.wav
# S207.wav
# S208.wav
# S209.wav
# S210.wav
# S236.wav
# S237.wav
# S238.wav
# S239.wav
# S240.wav
# S26.wav
# S266.wav
# S267.wav
# S268.wav
# S269.wav
# S27.wav
# S270.wav
# S28.wav
# S29.wav
# S296.wav
# S297.wav
# S298.wav
# S299.wav
# S30.wav
# S300.wav
# S326.wav
# S327.wav
# S328.wav
# S329.wav
# S330.wav
# S356.wav
# S357.wav
# S358.wav
# S359.wav
# S360.wav
# S386.wav
# S387.wav
# S388.wav
# S389.wav
# S390.wav
# S416.wav
# S417.wav
# S418.wav
# S419.wav
# S420.wav
# S446.wav
# S447.wav
# S448.wav
# S449.wav
# S450.wav
# S476.wav
# S477.wav
# S478.wav
# S479.wav
# S480.wav
# S506.wav
# S507.wav
# S508.wav
# S509.wav
# S510.wav
# S536.wav
# S537.wav
# S538.wav
# S539.wav
# S540.wav
# S56.wav
# S566.wav
# S567.wav
# S568.wav
# S569.wav
# S57.wav
# S570.wav
# S58.wav
# S59.wav
# S596.wav
# S597.wav
# S598.wav
# S599.wav
# S60.wav
# S600.wav
# S626.wav
# S627.wav
# S628.wav
# S629.wav
# S630.wav
# S656.wav
# S657.wav
# S658.wav
# S659.wav
# S660.wav
# S686.wav
# S687.wav
# S688.wav
# S689.wav
# S690.wav
# S716.wav
# S717.wav
# S718.wav
# S719.wav
# S720.wav
# S746.wav
# S747.wav
# S748.wav
# S749.wav
# S750.wav
# S776.wav
# S777.wav
# S778.wav
# S779.wav
# S780.wav
# S806.wav
# S807.wav
# S808.wav
# S809.wav
# S810.wav
# S836.wav
# S837.wav
# S838.wav
# S839.wav
# S840.wav
# S86.wav
# S866.wav
# S867.wav
# S868.wav
# S869.wav
# S87.wav
# S870.wav
# S88.wav
# S89.wav
# S896.wav
# S897.wav
# S898.wav
# S899.wav
# S90.wav
# S900.wav
# S926.wav
# S927.wav
# S928.wav
# S929.wav
# S930.wav
# S956.wav
# S957.wav
# S958.wav
# S959.wav
# S960.wav
# S986.wav
# S987.wav
# S988.wav
# S989.wav
# S990.wav
# [{'event_label': 'music',
#   'filename': 'S1016.wav',
#   'offset': 7.092651757,
#   'onset': 5.015974441},
#  {'event_label': 'music',
#   'filename': 'S1016.wav',
#   'offset': 8.370607029,
#   'onset': 7.635782748},
#  {'event_label': 'music',
#   'filename': 'S1016.wav',
#   'offset': 10.0,
#   'onset': 9.009584665},
#  {'event_label': 'speech',
#   'filename': 'S1016.wav',
#   'offset': 9.584664537,
#   'onset': 7.092651757},
#  {'event_label': 'music',
#   'filename': 'S1017.wav',
#   'offset': 8.785942492,
#   'onset': 5.367412141},
#  {'event_label': 'speech',
#   'filename': 'S1017.wav',
#   'offset': 6.677316294,
#   'onset': 5.015974441},
#  {'event_label': 'speech',
#   'filename': 'S1017.wav',
#   'offset': 9.968051118,
#   'onset': 8.785942492},
#  {'event_label': 'music',
#   'filename': 'S1018.wav',
#   'offset': 10.0,
#   'onset': 5.015974441},
#  {'event_label': 'music',
#   'filename': 'S1019.wav',
#   'offset': 10.0,
#   'onset': 5.015974441},
#  {'event_label': 'music',
#   'filename': 'S1020.wav',
#   'offset': 10.0,
#   'onset': 5.015974441},
#  {'event_label': 'music',
#   'filename': 'S116.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S116.wav',
#   'offset': 5.015943091,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S117.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S117.wav',
#   'offset': 5.015943091,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S118.wav',
#   'offset': 2.42809984,
#   'onset': 1.469639377},
#  {'event_label': 'music',
#   'filename': 'S118.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S118.wav',
#   'offset': 5.015943091,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S119.wav',
#   'offset': 9.9999375,
#   'onset': 7.028710064},
#  {'event_label': 'speech',
#   'filename': 'S119.wav',
#   'offset': 5.015943091,
#   'onset': 0.031948682},
#  {'event_label': 'speech',
#   'filename': 'S119.wav',
#   'offset': 9.488758586,
#   'onset': 8.626144169},
#  {'event_label': 'music',
#   'filename': 'S120.wav',
#   'offset': 9.9999375,
#   'onset': 7.028710064},
#  {'event_label': 'speech',
#   'filename': 'S120.wav',
#   'offset': 5.015943091,
#   'onset': 0.127794728},
#  {'event_label': 'music',
#   'filename': 'S146.wav',
#   'offset': 0.766768371,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S146.wav',
#   'offset': 2.587843251,
#   'onset': 1.757177516},
#  {'event_label': 'music',
#   'filename': 'S146.wav',
#   'offset': 9.9999375,
#   'onset': 6.006352236},
#  {'event_label': 'speech',
#   'filename': 'S146.wav',
#   'offset': 4.025533946,
#   'onset': 0.031948682},
#  {'event_label': 'speech',
#   'filename': 'S146.wav',
#   'offset': 7.795478435,
#   'onset': 6.261941693},
#  {'event_label': 'speech',
#   'filename': 'S146.wav',
#   'offset': 9.872142772,
#   'onset': 8.977579673},
#  {'event_label': 'music',
#   'filename': 'S147.wav',
#   'offset': 9.9999375,
#   'onset': 6.006352236},
#  {'event_label': 'speech',
#   'filename': 'S147.wav',
#   'offset': 4.025533946,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S148.wav',
#   'offset': 9.9999375,
#   'onset': 6.006352236},
#  {'event_label': 'speech',
#   'filename': 'S148.wav',
#   'offset': 4.025533946,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S149.wav',
#   'offset': 9.9999375,
#   'onset': 6.006352236},
#  {'event_label': 'speech',
#   'filename': 'S149.wav',
#   'offset': 4.025533946,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S150.wav',
#   'offset': 9.9999375,
#   'onset': 6.006352236},
#  {'event_label': 'speech',
#   'filename': 'S150.wav',
#   'offset': 4.025533946,
#   'onset': 0.063897364},
#  {'event_label': 'music',
#   'filename': 'S176.wav',
#   'offset': 9.9999375,
#   'onset': 4.952045727},
#  {'event_label': 'speech',
#   'filename': 'S176.wav',
#   'offset': 4.952045727,
#   'onset': 2.012766973},
#  {'event_label': 'music',
#   'filename': 'S177.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S177.wav',
#   'offset': 5.015943091,
#   'onset': 2.012766973},
#  {'event_label': 'music',
#   'filename': 'S178.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S178.wav',
#   'offset': 5.015943091,
#   'onset': 1.980818291},
#  {'event_label': 'music',
#   'filename': 'S179.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S179.wav',
#   'offset': 6.325839058,
#   'onset': 2.012766973},
#  {'event_label': 'music',
#   'filename': 'S180.wav',
#   'offset': 9.9999375,
#   'onset': 3.801893171},
#  {'event_label': 'speech',
#   'filename': 'S180.wav',
#   'offset': 4.888148363,
#   'onset': 1.980818291},
#  {'event_label': 'music',
#   'filename': 'S206.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S206.wav',
#   'offset': 9.9999375,
#   'onset': 6.006352236},
#  {'event_label': 'music',
#   'filename': 'S207.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S207.wav',
#   'offset': 9.9999375,
#   'onset': 5.974403554},
#  {'event_label': 'music',
#   'filename': 'S208.wav',
#   'offset': 3.0351248,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S208.wav',
#   'offset': 9.9999375,
#   'onset': 5.974403554},
#  {'event_label': 'music',
#   'filename': 'S209.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S209.wav',
#   'offset': 9.967988818,
#   'onset': 5.974403554},
#  {'event_label': 'music',
#   'filename': 'S210.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S210.wav',
#   'offset': 9.967988818,
#   'onset': 6.006352236},
#  {'event_label': 'music',
#   'filename': 'S236.wav',
#   'offset': 0.894563099,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S236.wav',
#   'offset': 9.9999375,
#   'onset': 5.047891773},
#  {'event_label': 'speech',
#   'filename': 'S236.wav',
#   'offset': 2.044715655,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S237.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S237.wav',
#   'offset': 2.012766973,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S238.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S238.wav',
#   'offset': 2.044715655,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S239.wav',
#   'offset': 7.539888978,
#   'onset': 5.015943091},
#  {'event_label': 'music',
#   'filename': 'S239.wav',
#   'offset': 9.041477037,
#   'onset': 8.210811302},
#  {'event_label': 'speech',
#   'filename': 'S239.wav',
#   'offset': 2.012766973,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S239.wav',
#   'offset': 9.967988818,
#   'onset': 4.983994409},
#  {'event_label': 'music',
#   'filename': 'S240.wav',
#   'offset': 9.9999375,
#   'onset': 4.983994409},
#  {'event_label': 'speech',
#   'filename': 'S240.wav',
#   'offset': 2.012766973,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S26.wav',
#   'offset': 6.389776358,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S26.wav',
#   'offset': 7.699680511,
#   'onset': 6.900958466},
#  {'event_label': 'speech',
#   'filename': 'S26.wav',
#   'offset': 10.0,
#   'onset': 5.942492013},
#  {'event_label': 'music',
#   'filename': 'S266.wav',
#   'offset': 1.022364217,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S266.wav',
#   'offset': 6.038338658,
#   'onset': 1.022364217},
#  {'event_label': 'music',
#   'filename': 'S267.wav',
#   'offset': 1.022364217,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S267.wav',
#   'offset': 6.038338658,
#   'onset': 1.022364217},
#  {'event_label': 'music',
#   'filename': 'S268.wav',
#   'offset': 4.600638978,
#   'onset': 3.322683706},
#  {'event_label': 'speech',
#   'filename': 'S268.wav',
#   'offset': 6.038338658,
#   'onset': 0.031948882},
#  {'event_label': 'music',
#   'filename': 'S269.wav',
#   'offset': 1.277955272,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S269.wav',
#   'offset': 6.006389776,
#   'onset': 0.990415335},
#  {'event_label': 'music',
#   'filename': 'S27.wav',
#   'offset': 5.015974441,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S27.wav',
#   'offset': 3.322683706,
#   'onset': 0.607028754},
#  {'event_label': 'speech',
#   'filename': 'S27.wav',
#   'offset': 10.0,
#   'onset': 5.015974441},
#  {'event_label': 'music',
#   'filename': 'S270.wav',
#   'offset': 1.022364217,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S270.wav',
#   'offset': 6.038338658,
#   'onset': 1.022364217},
#  {'event_label': 'music',
#   'filename': 'S28.wav',
#   'offset': 4.984025559,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S28.wav',
#   'offset': 10.0,
#   'onset': 4.984025559},
#  {'event_label': 'music',
#   'filename': 'S29.wav',
#   'offset': 5.015974441,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S29.wav',
#   'offset': 10.0,
#   'onset': 5.015974441},
#  {'event_label': 'music',
#   'filename': 'S296.wav',
#   'offset': 3.993585264,
#   'onset': 0.543127596},
#  {'event_label': 'speech',
#   'filename': 'S296.wav',
#   'offset': 1.022357827,
#   'onset': 0.031948682},
#  {'event_label': 'speech',
#   'filename': 'S296.wav',
#   'offset': 9.9999375,
#   'onset': 7.987170527},
#  {'event_label': 'music',
#   'filename': 'S297.wav',
#   'offset': 4.025533946,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S297.wav',
#   'offset': 9.904091454,
#   'onset': 7.987170527},
#  {'event_label': 'music',
#   'filename': 'S298.wav',
#   'offset': 4.025533946,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S298.wav',
#   'offset': 9.9999375,
#   'onset': 7.987170527},
#  {'event_label': 'music',
#   'filename': 'S299.wav',
#   'offset': 3.993585264,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S299.wav',
#   'offset': 9.9999375,
#   'onset': 7.987170527},
#  {'event_label': 'music',
#   'filename': 'S30.wav',
#   'offset': 5.015974441,
#   'onset': 0.031948882},
#  {'event_label': 'music',
#   'filename': 'S30.wav',
#   'offset': 8.913738019,
#   'onset': 7.987220447},
#  {'event_label': 'speech',
#   'filename': 'S30.wav',
#   'offset': 10.0,
#   'onset': 5.015974441},
#  {'event_label': 'music',
#   'filename': 'S300.wav',
#   'offset': 4.025533946,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S300.wav',
#   'offset': 9.9999375,
#   'onset': 7.987170527},
#  {'event_label': 'music',
#   'filename': 'S326.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S326.wav',
#   'offset': 5.015943091,
#   'onset': 3.993585264},
#  {'event_label': 'music',
#   'filename': 'S327.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S327.wav',
#   'offset': 5.015943091,
#   'onset': 3.993585264},
#  {'event_label': 'speech',
#   'filename': 'S327.wav',
#   'offset': 7.220402157,
#   'onset': 6.421685104},
#  {'event_label': 'music',
#   'filename': 'S328.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S328.wav',
#   'offset': 5.015943091,
#   'onset': 3.993585264},
#  {'event_label': 'music',
#   'filename': 'S329.wav',
#   'offset': 9.9999375,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S329.wav',
#   'offset': 5.015943091,
#   'onset': 3.993585264},
#  {'event_label': 'music',
#   'filename': 'S330.wav',
#   'offset': 8.849784944,
#   'onset': 6.613377196},
#  {'event_label': 'speech',
#   'filename': 'S330.wav',
#   'offset': 8.210811302,
#   'onset': 3.993585264},
#  {'event_label': 'speech',
#   'filename': 'S330.wav',
#   'offset': 9.808245407,
#   'onset': 8.849784944},
#  {'event_label': 'music',
#   'filename': 'S356.wav',
#   'offset': 6.006314696,
#   'onset': 3.993560304},
#  {'event_label': 'music',
#   'filename': 'S356.wav',
#   'offset': 9.169214457,
#   'onset': 8.242708466},
#  {'event_label': 'speech',
#   'filename': 'S356.wav',
#   'offset': 2.044702875,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S356.wav',
#   'offset': 9.999875,
#   'onset': 7.987120607},
#  {'event_label': 'music',
#   'filename': 'S357.wav',
#   'offset': 6.006314696,
#   'onset': 4.025508786},
#  {'event_label': 'speech',
#   'filename': 'S357.wav',
#   'offset': 2.044702875,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S357.wav',
#   'offset': 9.967926518,
#   'onset': 7.987120607},
#  {'event_label': 'music',
#   'filename': 'S358.wav',
#   'offset': 6.006314696,
#   'onset': 3.993560304},
#  {'event_label': 'music',
#   'filename': 'S358.wav',
#   'offset': 8.977523562,
#   'onset': 8.051017572},
#  {'event_label': 'speech',
#   'filename': 'S358.wav',
#   'offset': 2.044702875,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S358.wav',
#   'offset': 9.999875,
#   'onset': 8.977523562},
#  {'event_label': 'music',
#   'filename': 'S359.wav',
#   'offset': 1.214042332,
#   'onset': 0.223639377},
#  {'event_label': 'music',
#   'filename': 'S359.wav',
#   'offset': 9.009472045,
#   'onset': 7.987120607},
#  {'event_label': 'speech',
#   'filename': 'S359.wav',
#   'offset': 2.044702875,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S359.wav',
#   'offset': 6.006314696,
#   'onset': 3.993560304},
#  {'event_label': 'speech',
#   'filename': 'S359.wav',
#   'offset': 9.999875,
#   'onset': 8.94557508},
#  {'event_label': 'music',
#   'filename': 'S360.wav',
#   'offset': 6.006314696,
#   'onset': 3.993560304},
#  {'event_label': 'music',
#   'filename': 'S360.wav',
#   'offset': 8.977523562,
#   'onset': 7.987120607},
#  {'event_label': 'speech',
#   'filename': 'S360.wav',
#   'offset': 2.044702875,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S360.wav',
#   'offset': 9.967926518,
#   'onset': 8.977523562},
#  {'event_label': 'music',
#   'filename': 'S386.wav',
#   'offset': 2.076677316,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S386.wav',
#   'offset': 6.996805112,
#   'onset': 4.025559105},
#  {'event_label': 'music',
#   'filename': 'S386.wav',
#   'offset': 10.0,
#   'onset': 8.370607029},
#  {'event_label': 'speech',
#   'filename': 'S386.wav',
#   'offset': 4.025559105,
#   'onset': 2.076677316},
#  {'event_label': 'speech',
#   'filename': 'S386.wav',
#   'offset': 9.968051118,
#   'onset': 6.996805112},
#  {'event_label': 'music',
#   'filename': 'S387.wav',
#   'offset': 2.012779553,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S387.wav',
#   'offset': 7.028753994,
#   'onset': 3.993610224},
#  {'event_label': 'speech',
#   'filename': 'S387.wav',
#   'offset': 4.28115016,
#   'onset': 1.757188498},
#  {'event_label': 'speech',
#   'filename': 'S387.wav',
#   'offset': 10.0,
#   'onset': 7.028753994},
#  {'event_label': 'music',
#   'filename': 'S388.wav',
#   'offset': 2.555910543,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S388.wav',
#   'offset': 7.060702875,
#   'onset': 3.993610224},
#  {'event_label': 'speech',
#   'filename': 'S388.wav',
#   'offset': 3.993610224,
#   'onset': 2.076677316},
#  {'event_label': 'speech',
#   'filename': 'S388.wav',
#   'offset': 10.0,
#   'onset': 7.060702875},
#  {'event_label': 'music',
#   'filename': 'S389.wav',
#   'offset': 2.555910543,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S389.wav',
#   'offset': 7.31629393,
#   'onset': 3.57827476},
#  {'event_label': 'speech',
#   'filename': 'S389.wav',
#   'offset': 4.025559105,
#   'onset': 2.012779553},
#  {'event_label': 'speech',
#   'filename': 'S389.wav',
#   'offset': 10.0,
#   'onset': 6.932907348},
#  {'event_label': 'music',
#   'filename': 'S390.wav',
#   'offset': 2.907348243,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S390.wav',
#   'offset': 6.932907348,
#   'onset': 4.025559105},
#  {'event_label': 'speech',
#   'filename': 'S390.wav',
#   'offset': 4.025559105,
#   'onset': 2.012779553},
#  {'event_label': 'speech',
#   'filename': 'S390.wav',
#   'offset': 6.102236422,
#   'onset': 4.568690096},
#  {'event_label': 'speech',
#   'filename': 'S390.wav',
#   'offset': 10.0,
#   'onset': 6.677316294},
#  {'event_label': 'music',
#   'filename': 'S416.wav',
#   'offset': 4.984025559,
#   'onset': 2.012779553},
#  {'event_label': 'music',
#   'filename': 'S416.wav',
#   'offset': 10.0,
#   'onset': 8.019169329},
#  {'event_label': 'speech',
#   'filename': 'S416.wav',
#   'offset': 3.514376997,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S416.wav',
#   'offset': 8.019169329,
#   'onset': 4.089456869},
#  {'event_label': 'music',
#   'filename': 'S417.wav',
#   'offset': 4.984025559,
#   'onset': 2.012779553},
#  {'event_label': 'music',
#   'filename': 'S417.wav',
#   'offset': 6.709265176,
#   'onset': 5.71884984},
#  {'event_label': 'music',
#   'filename': 'S417.wav',
#   'offset': 10.0,
#   'onset': 8.019169329},
#  {'event_label': 'speech',
#   'filename': 'S417.wav',
#   'offset': 2.012779553,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S417.wav',
#   'offset': 9.233226837,
#   'onset': 4.984025559},
#  {'event_label': 'music',
#   'filename': 'S418.wav',
#   'offset': 5.399361022,
#   'onset': 0.702875399},
#  {'event_label': 'music',
#   'filename': 'S418.wav',
#   'offset': 10.0,
#   'onset': 7.603833866},
#  {'event_label': 'speech',
#   'filename': 'S418.wav',
#   'offset': 2.044728435,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S418.wav',
#   'offset': 8.083067093,
#   'onset': 4.760383387},
#  {'event_label': 'music',
#   'filename': 'S419.wav',
#   'offset': 1.118210863,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S419.wav',
#   'offset': 5.015974441,
#   'onset': 1.661341853},
#  {'event_label': 'music',
#   'filename': 'S419.wav',
#   'offset': 10.0,
#   'onset': 8.019169329},
#  {'event_label': 'speech',
#   'filename': 'S419.wav',
#   'offset': 2.012779553,
#   'onset': 0.095846645},
#  {'event_label': 'speech',
#   'filename': 'S419.wav',
#   'offset': 8.019169329,
#   'onset': 5.015974441},
#  {'event_label': 'music',
#   'filename': 'S420.wav',
#   'offset': 4.952076677,
#   'onset': 2.012779553},
#  {'event_label': 'music',
#   'filename': 'S420.wav',
#   'offset': 10.0,
#   'onset': 7.827476038},
#  {'event_label': 'speech',
#   'filename': 'S420.wav',
#   'offset': 2.012779553,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S420.wav',
#   'offset': 8.019169329,
#   'onset': 4.952076677},
#  {'event_label': 'music',
#   'filename': 'S446.wav',
#   'offset': 5.015943091,
#   'onset': 3.003176118},
#  {'event_label': 'music',
#   'filename': 'S446.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S446.wav',
#   'offset': 3.003176118,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S447.wav',
#   'offset': 5.015943091,
#   'onset': 3.003176118},
#  {'event_label': 'music',
#   'filename': 'S447.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S447.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S448.wav',
#   'offset': 5.015943091,
#   'onset': 3.067073482},
#  {'event_label': 'music',
#   'filename': 'S448.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S448.wav',
#   'offset': 4.440866813,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S449.wav',
#   'offset': 4.983994409,
#   'onset': 3.0351248},
#  {'event_label': 'music',
#   'filename': 'S449.wav',
#   'offset': 8.114965256,
#   'onset': 6.996761382},
#  {'event_label': 'music',
#   'filename': 'S449.wav',
#   'offset': 9.904091454,
#   'onset': 8.913682308},
#  {'event_label': 'speech',
#   'filename': 'S449.wav',
#   'offset': 3.0351248,
#   'onset': 0.031948682},
#  {'event_label': 'speech',
#   'filename': 'S449.wav',
#   'offset': 9.265117812,
#   'onset': 8.114965256},
#  {'event_label': 'music',
#   'filename': 'S450.wav',
#   'offset': 4.983994409,
#   'onset': 3.0351248},
#  {'event_label': 'music',
#   'filename': 'S450.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S450.wav',
#   'offset': 3.0351248,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S476.wav',
#   'offset': 8.051017572,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S476.wav',
#   'offset': 3.035105831,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S476.wav',
#   'offset': 9.999875,
#   'onset': 7.987120607},
#  {'event_label': 'speech',
#   'filename': 'S477.wav',
#   'offset': 3.035105831,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S477.wav',
#   'offset': 9.967926518,
#   'onset': 6.006314696},
#  {'event_label': 'music',
#   'filename': 'S478.wav',
#   'offset': 7.987120607,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S478.wav',
#   'offset': 3.035105831,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S478.wav',
#   'offset': 9.999875,
#   'onset': 7.987120607},
#  {'event_label': 'music',
#   'filename': 'S479.wav',
#   'offset': 8.019069089,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S479.wav',
#   'offset': 3.035105831,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S479.wav',
#   'offset': 9.999875,
#   'onset': 8.019069089},
#  {'event_label': 'music',
#   'filename': 'S480.wav',
#   'offset': 9.297008387,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S480.wav',
#   'offset': 3.035105831,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S480.wav',
#   'offset': 9.999875,
#   'onset': 7.987120607},
#  {'event_label': 'music',
#   'filename': 'S506.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S506.wav',
#   'offset': 3.0351248,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S507.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S507.wav',
#   'offset': 2.044715655,
#   'onset': 0.031948682},
#  {'event_label': 'speech',
#   'filename': 'S507.wav',
#   'offset': 9.105374401,
#   'onset': 7.603786342},
#  {'event_label': 'music',
#   'filename': 'S508.wav',
#   'offset': 2.683689297,
#   'onset': 1.693280152},
#  {'event_label': 'music',
#   'filename': 'S508.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S508.wav',
#   'offset': 3.003176118,
#   'onset': 0.031948682},
#  {'event_label': 'speech',
#   'filename': 'S509.wav',
#   'offset': 3.0351248,
#   'onset': 0.031948682},
#  {'event_label': 'speech',
#   'filename': 'S509.wav',
#   'offset': 9.967988818,
#   'onset': 6.996761382},
#  {'event_label': 'music',
#   'filename': 'S510.wav',
#   'offset': 2.939278754,
#   'onset': 2.076664337},
#  {'event_label': 'music',
#   'filename': 'S510.wav',
#   'offset': 9.9999375,
#   'onset': 6.996761382},
#  {'event_label': 'speech',
#   'filename': 'S510.wav',
#   'offset': 3.0351248,
#   'onset': 0.031948682},
#  {'event_label': 'music',
#   'filename': 'S536.wav',
#   'offset': 7.987120607,
#   'onset': 6.293851038},
#  {'event_label': 'speech',
#   'filename': 'S536.wav',
#   'offset': 3.035105831,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S536.wav',
#   'offset': 9.999875,
#   'onset': 7.348150958},
#  {'event_label': 'music',
#   'filename': 'S537.wav',
#   'offset': 8.019069089,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S537.wav',
#   'offset': 3.035105831,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S537.wav',
#   'offset': 9.935978035,
#   'onset': 8.019069089},
#  {'event_label': 'music',
#   'filename': 'S538.wav',
#   'offset': 8.68998722,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S538.wav',
#   'offset': 3.035105831,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S538.wav',
#   'offset': 9.999875,
#   'onset': 7.987120607},
#  {'event_label': 'music',
#   'filename': 'S539.wav',
#   'offset': 8.913626597,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S539.wav',
#   'offset': 3.035105831,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S539.wav',
#   'offset': 9.999875,
#   'onset': 8.019069089},
#  {'event_label': 'music',
#   'filename': 'S540.wav',
#   'offset': 6.964769169,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S540.wav',
#   'offset': 3.035105831,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S540.wav',
#   'offset': 9.999875,
#   'onset': 5.974366214},
#  {'event_label': 'music',
#   'filename': 'S56.wav',
#   'offset': 5.015943091,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S56.wav',
#   'offset': 9.967988818,
#   'onset': 5.974403554},
#  {'event_label': 'music',
#   'filename': 'S566.wav',
#   'offset': 8.019069089,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S566.wav',
#   'offset': 3.035105831,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S566.wav',
#   'offset': 9.999875,
#   'onset': 7.443996406},
#  {'event_label': 'music',
#   'filename': 'S567.wav',
#   'offset': 7.987120607,
#   'onset': 6.038263179},
#  {'event_label': 'speech',
#   'filename': 'S567.wav',
#   'offset': 3.035105831,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S567.wav',
#   'offset': 9.999875,
#   'onset': 7.987120607},
#  {'event_label': 'music',
#   'filename': 'S568.wav',
#   'offset': 8.019069089,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S568.wav',
#   'offset': 3.035105831,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S568.wav',
#   'offset': 9.999875,
#   'onset': 8.019069089},
#  {'event_label': 'music',
#   'filename': 'S569.wav',
#   'offset': 8.082966054,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S569.wav',
#   'offset': 3.035105831,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S569.wav',
#   'offset': 9.999875,
#   'onset': 7.987120607},
#  {'event_label': 'music',
#   'filename': 'S57.wav',
#   'offset': 2.87538139,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S57.wav',
#   'offset': 4.983994409,
#   'onset': 3.706047125},
#  {'event_label': 'speech',
#   'filename': 'S57.wav',
#   'offset': 3.706047125,
#   'onset': 2.87538139},
#  {'event_label': 'speech',
#   'filename': 'S57.wav',
#   'offset': 9.9999375,
#   'onset': 5.974403554},
#  {'event_label': 'music',
#   'filename': 'S570.wav',
#   'offset': 8.019069089,
#   'onset': 6.006314696},
#  {'event_label': 'speech',
#   'filename': 'S570.wav',
#   'offset': 3.003157348,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S570.wav',
#   'offset': 9.999875,
#   'onset': 8.019069089},
#  {'event_label': 'music',
#   'filename': 'S58.wav',
#   'offset': 4.153328674,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S58.wav',
#   'offset': 5.015943091,
#   'onset': 4.153328674},
#  {'event_label': 'speech',
#   'filename': 'S58.wav',
#   'offset': 9.9999375,
#   'onset': 6.006352236},
#  {'event_label': 'music',
#   'filename': 'S59.wav',
#   'offset': 5.015943091,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S59.wav',
#   'offset': 9.9999375,
#   'onset': 6.006352236},
#  {'event_label': 'music',
#   'filename': 'S596.wav',
#   'offset': 6.006314696,
#   'onset': 5.015911741},
#  {'event_label': 'speech',
#   'filename': 'S596.wav',
#   'offset': 2.012754393,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S596.wav',
#   'offset': 9.999875,
#   'onset': 6.006314696},
#  {'event_label': 'music',
#   'filename': 'S597.wav',
#   'offset': 5.974366214,
#   'onset': 5.015911741},
#  {'event_label': 'speech',
#   'filename': 'S597.wav',
#   'offset': 2.044702875,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S597.wav',
#   'offset': 9.999875,
#   'onset': 5.974366214},
#  {'event_label': 'speech',
#   'filename': 'S598.wav',
#   'offset': 2.044702875,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S598.wav',
#   'offset': 9.999875,
#   'onset': 5.015911741},
#  {'event_label': 'music',
#   'filename': 'S599.wav',
#   'offset': 6.006314696,
#   'onset': 5.015911741},
#  {'event_label': 'speech',
#   'filename': 'S599.wav',
#   'offset': 2.044702875,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S599.wav',
#   'offset': 9.999875,
#   'onset': 6.006314696},
#  {'event_label': 'music',
#   'filename': 'S60.wav',
#   'offset': 5.015943091,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S60.wav',
#   'offset': 9.9999375,
#   'onset': 5.974403554},
#  {'event_label': 'music',
#   'filename': 'S600.wav',
#   'offset': 6.006314696,
#   'onset': 5.015911741},
#  {'event_label': 'speech',
#   'filename': 'S600.wav',
#   'offset': 2.044702875,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S600.wav',
#   'offset': 9.999875,
#   'onset': 6.006314696},
#  {'event_label': 'music',
#   'filename': 'S626.wav',
#   'offset': 9.999875,
#   'onset': 8.178811502},
#  {'event_label': 'speech',
#   'filename': 'S626.wav',
#   'offset': 1.022351438,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S626.wav',
#   'offset': 8.977523562,
#   'onset': 4.983963259},
#  {'event_label': 'speech',
#   'filename': 'S627.wav',
#   'offset': 1.022351438,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S627.wav',
#   'offset': 9.808184105,
#   'onset': 4.983963259},
#  {'event_label': 'music',
#   'filename': 'S628.wav',
#   'offset': 9.935978035,
#   'onset': 9.009472045},
#  {'event_label': 'speech',
#   'filename': 'S628.wav',
#   'offset': 1.05429992,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S628.wav',
#   'offset': 9.999875,
#   'onset': 4.983963259},
#  {'event_label': 'music',
#   'filename': 'S629.wav',
#   'offset': 9.999875,
#   'onset': 9.009472045},
#  {'event_label': 'speech',
#   'filename': 'S629.wav',
#   'offset': 1.022351438,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S629.wav',
#   'offset': 9.009472045,
#   'onset': 4.983963259},
#  {'event_label': 'music',
#   'filename': 'S630.wav',
#   'offset': 6.677232827,
#   'onset': 5.782675319},
#  {'event_label': 'music',
#   'filename': 'S630.wav',
#   'offset': 9.999875,
#   'onset': 9.009472045},
#  {'event_label': 'speech',
#   'filename': 'S630.wav',
#   'offset': 1.022351438,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S630.wav',
#   'offset': 9.009472045,
#   'onset': 4.983963259},
#  {'event_label': 'music',
#   'filename': 'S656.wav',
#   'offset': 3.993560304,
#   'onset': 3.035105831},
#  {'event_label': 'music',
#   'filename': 'S656.wav',
#   'offset': 9.999875,
#   'onset': 7.028666134},
#  {'event_label': 'speech',
#   'filename': 'S656.wav',
#   'offset': 3.035105831,
#   'onset': 0.095845447},
#  {'event_label': 'speech',
#   'filename': 'S656.wav',
#   'offset': 7.028666134,
#   'onset': 5.974366214},
#  {'event_label': 'music',
#   'filename': 'S657.wav',
#   'offset': 3.993560304,
#   'onset': 2.939260383},
#  {'event_label': 'music',
#   'filename': 'S657.wav',
#   'offset': 9.999875,
#   'onset': 6.900872204},
#  {'event_label': 'speech',
#   'filename': 'S657.wav',
#   'offset': 2.939260383,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S657.wav',
#   'offset': 6.900872204,
#   'onset': 6.006314696},
#  {'event_label': 'music',
#   'filename': 'S658.wav',
#   'offset': 3.993560304,
#   'onset': 3.003157348},
#  {'event_label': 'music',
#   'filename': 'S658.wav',
#   'offset': 9.967926518,
#   'onset': 6.996717652},
#  {'event_label': 'speech',
#   'filename': 'S658.wav',
#   'offset': 3.003157348,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S658.wav',
#   'offset': 6.996717652,
#   'onset': 5.974366214},
#  {'event_label': 'music',
#   'filename': 'S659.wav',
#   'offset': 0.766763578,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S659.wav',
#   'offset': 4.025508786,
#   'onset': 3.003157348},
#  {'event_label': 'music',
#   'filename': 'S659.wav',
#   'offset': 9.999875,
#   'onset': 6.996717652},
#  {'event_label': 'speech',
#   'filename': 'S659.wav',
#   'offset': 3.003157348,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S659.wav',
#   'offset': 6.996717652,
#   'onset': 6.006314696},
#  {'event_label': 'music',
#   'filename': 'S660.wav',
#   'offset': 3.993560304,
#   'onset': 2.555878594},
#  {'event_label': 'music',
#   'filename': 'S660.wav',
#   'offset': 9.999875,
#   'onset': 6.996717652},
#  {'event_label': 'speech',
#   'filename': 'S660.wav',
#   'offset': 3.16289976,
#   'onset': 0.031948482},
#  {'event_label': 'speech',
#   'filename': 'S660.wav',
#   'offset': 6.996717652,
#   'onset': 5.974366214},
#  {'event_label': 'music',
#   'filename': 'S686.wav',
#   'offset': 3.0351248,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S686.wav',
#   'offset': 9.9999375,
#   'onset': 8.977579673},
#  {'event_label': 'music',
#   'filename': 'S687.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S687.wav',
#   'offset': 9.9999375,
#   'onset': 8.977579673},
#  {'event_label': 'music',
#   'filename': 'S688.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S688.wav',
#   'offset': 9.9999375,
#   'onset': 8.977579673},
#  {'event_label': 'music',
#   'filename': 'S689.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S689.wav',
#   'offset': 9.9999375,
#   'onset': 8.977579673},
#  {'event_label': 'music',
#   'filename': 'S690.wav',
#   'offset': 3.003176118,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S690.wav',
#   'offset': 9.9999375,
#   'onset': 8.977579673},
#  {'event_label': 'music',
#   'filename': 'S716.wav',
#   'offset': 9.9999375,
#   'onset': 8.019119209},
#  {'event_label': 'speech',
#   'filename': 'S716.wav',
#   'offset': 8.019119209,
#   'onset': 5.974403554},
#  {'event_label': 'music',
#   'filename': 'S717.wav',
#   'offset': 9.9999375,
#   'onset': 8.019119209},
#  {'event_label': 'speech',
#   'filename': 'S717.wav',
#   'offset': 8.019119209,
#   'onset': 5.974403554},
#  {'event_label': 'music',
#   'filename': 'S718.wav',
#   'offset': 9.9999375,
#   'onset': 8.019119209},
#  {'event_label': 'speech',
#   'filename': 'S718.wav',
#   'offset': 8.019119209,
#   'onset': 6.006352236},
#  {'event_label': 'music',
#   'filename': 'S719.wav',
#   'offset': 9.9999375,
#   'onset': 8.019119209},
#  {'event_label': 'speech',
#   'filename': 'S719.wav',
#   'offset': 7.284299521,
#   'onset': 6.006352236},
#  {'event_label': 'music',
#   'filename': 'S720.wav',
#   'offset': 9.9999375,
#   'onset': 7.987170527},
#  {'event_label': 'speech',
#   'filename': 'S720.wav',
#   'offset': 8.17886262,
#   'onset': 6.006352236},
#  {'event_label': 'speech',
#   'filename': 'S746.wav',
#   'offset': 10.0,
#   'onset': 8.977635783},
#  {'event_label': 'speech',
#   'filename': 'S747.wav',
#   'offset': 10.0,
#   'onset': 8.977635783},
#  {'event_label': 'speech',
#   'filename': 'S748.wav',
#   'offset': 10.0,
#   'onset': 9.009584665},
#  {'event_label': 'speech',
#   'filename': 'S749.wav',
#   'offset': 10.0,
#   'onset': 8.977635783},
#  {'event_label': 'speech',
#   'filename': 'S750.wav',
#   'offset': 9.968051118,
#   'onset': 8.977635783},
#  {'event_label': 'speech',
#   'filename': 'S776.wav',
#   'offset': 2.012779553,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S777.wav',
#   'offset': 2.044728435,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S778.wav',
#   'offset': 2.012779553,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S779.wav',
#   'offset': 2.044728435,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S780.wav',
#   'offset': 2.044728435,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S806.wav',
#   'offset': 10.0,
#   'onset': 6.996805112},
#  {'event_label': 'music',
#   'filename': 'S807.wav',
#   'offset': 7.923322684,
#   'onset': 7.220447284},
#  {'event_label': 'speech',
#   'filename': 'S807.wav',
#   'offset': 10.0,
#   'onset': 6.996805112},
#  {'event_label': 'speech',
#   'filename': 'S808.wav',
#   'offset': 9.936102236,
#   'onset': 6.996805112},
#  {'event_label': 'speech',
#   'filename': 'S809.wav',
#   'offset': 9.968051118,
#   'onset': 6.996805112},
#  {'event_label': 'music',
#   'filename': 'S810.wav',
#   'offset': 10.0,
#   'onset': 7.028753994},
#  {'event_label': 'speech',
#   'filename': 'S810.wav',
#   'offset': 8.051118211,
#   'onset': 6.96485623},
#  {'event_label': 'speech',
#   'filename': 'S810.wav',
#   'offset': 9.904153355,
#   'onset': 8.722044728},
#  {'event_label': 'speech',
#   'filename': 'S836.wav',
#   'offset': 4.025559105,
#   'onset': 0.031948882},
#  {'event_label': 'music',
#   'filename': 'S837.wav',
#   'offset': 1.118210863,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S837.wav',
#   'offset': 4.025559105,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S838.wav',
#   'offset': 1.054313099,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S838.wav',
#   'offset': 3.92971246,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S839.wav',
#   'offset': 4.025559105,
#   'onset': 0.031948882},
#  {'event_label': 'speech',
#   'filename': 'S840.wav',
#   'offset': 4.025559105,
#   'onset': 0.031948882},
#  {'event_label': 'music',
#   'filename': 'S86.wav',
#   'offset': 3.993585264,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S86.wav',
#   'offset': 1.05430651,
#   'onset': 0.255589457},
#  {'event_label': 'speech',
#   'filename': 'S86.wav',
#   'offset': 9.9999375,
#   'onset': 4.983994409},
#  {'event_label': 'speech',
#   'filename': 'S866.wav',
#   'offset': 10.0,
#   'onset': 4.984025559},
#  {'event_label': 'music',
#   'filename': 'S867.wav',
#   'offset': 9.329073482,
#   'onset': 7.731629393},
#  {'event_label': 'speech',
#   'filename': 'S867.wav',
#   'offset': 10.0,
#   'onset': 5.015974441},
#  {'event_label': 'speech',
#   'filename': 'S868.wav',
#   'offset': 9.968051118,
#   'onset': 4.984025559},
#  {'event_label': 'music',
#   'filename': 'S869.wav',
#   'offset': 6.517571885,
#   'onset': 5.463258786},
#  {'event_label': 'speech',
#   'filename': 'S869.wav',
#   'offset': 9.968051118,
#   'onset': 4.984025559},
#  {'event_label': 'music',
#   'filename': 'S87.wav',
#   'offset': 3.993585264,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S87.wav',
#   'offset': 9.967988818,
#   'onset': 4.983994409},
#  {'event_label': 'speech',
#   'filename': 'S870.wav',
#   'offset': 9.968051118,
#   'onset': 4.984025559},
#  {'event_label': 'music',
#   'filename': 'S88.wav',
#   'offset': 4.025533946,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S88.wav',
#   'offset': 9.967988818,
#   'onset': 4.983994409},
#  {'event_label': 'music',
#   'filename': 'S89.wav',
#   'offset': 3.993585264,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S89.wav',
#   'offset': 8.530298123,
#   'onset': 5.015943091},
#  {'event_label': 'speech',
#   'filename': 'S89.wav',
#   'offset': 9.9999375,
#   'onset': 4.983994409},
#  {'event_label': 'music',
#   'filename': 'S896.wav',
#   'offset': 10.0,
#   'onset': 9.009584665},
#  {'event_label': 'music',
#   'filename': 'S897.wav',
#   'offset': 10.0,
#   'onset': 9.009584665},
#  {'event_label': 'music',
#   'filename': 'S898.wav',
#   'offset': 10.0,
#   'onset': 9.041533546},
#  {'event_label': 'music',
#   'filename': 'S899.wav',
#   'offset': 10.0,
#   'onset': 8.977635783},
#  {'event_label': 'music',
#   'filename': 'S90.wav',
#   'offset': 3.993585264,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S90.wav',
#   'offset': 9.967988818,
#   'onset': 4.983994409},
#  {'event_label': 'music',
#   'filename': 'S900.wav',
#   'offset': 10.0,
#   'onset': 9.009584665},
#  {'event_label': 'music',
#   'filename': 'S926.wav',
#   'offset': 2.012779553,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S927.wav',
#   'offset': 2.012779553,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S927.wav',
#   'offset': 0.830670927,
#   'onset': 0.063897764},
#  {'event_label': 'music',
#   'filename': 'S928.wav',
#   'offset': 2.012779553,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S929.wav',
#   'offset': 2.012779553,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S929.wav',
#   'offset': 0.990415335,
#   'onset': 0.127795527},
#  {'event_label': 'music',
#   'filename': 'S930.wav',
#   'offset': 1.980830671,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S956.wav',
#   'offset': 10.0,
#   'onset': 7.028753994},
#  {'event_label': 'music',
#   'filename': 'S957.wav',
#   'offset': 10.0,
#   'onset': 6.996805112},
#  {'event_label': 'music',
#   'filename': 'S958.wav',
#   'offset': 10.0,
#   'onset': 6.996805112},
#  {'event_label': 'music',
#   'filename': 'S959.wav',
#   'offset': 10.0,
#   'onset': 6.996805112},
#  {'event_label': 'music',
#   'filename': 'S960.wav',
#   'offset': 10.0,
#   'onset': 6.996805112},
#  {'event_label': 'music',
#   'filename': 'S986.wav',
#   'offset': 4.025559105,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S987.wav',
#   'offset': 3.993610224,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S988.wav',
#   'offset': 3.993610224,
#   'onset': 0.0},
#  {'event_label': 'music',
#   'filename': 'S989.wav',
#   'offset': 4.025559105,
#   'onset': 0.0},
#  {'event_label': 'speech',
#   'filename': 'S989.wav',
#   'offset': 2.651757188,
#   'onset': 1.916932907},
#  {'event_label': 'music',
#   'filename': 'S990.wav',
#   'offset': 4.025559105,
#   'onset': 0.0}]

# %% [markdown]
# ## Preparing data for evaluation

# %% [markdown]
# Prepare reference data and estimated to have filenames in uniform format:

# %%
validation_data = csv_to_meta_container('/content/drive/MyDrive/Ee603_mlsp/Project/validation.csv')
# Out:
# MetaDataContainer :: Class
# Items                               : 360
# Unique
#   Files                             : 170
#   Scene labels                      : 0
#   Event labels                      : 2
#   Tags                              : 0
#   Identifiers                       : 0
#   Source labels                     : 0
#
# Meta data
#   Source                  Onset   Offset   Scene             Event             Tags              Identifier
#   --------------------   ------   ------   ---------------   ---------------   ---------------   -----
#   S26                      0.00     5.00   -                 music             -                 -
#   S26                      5.00    10.00   -                 speech            -                 -
#   S27                      0.00     5.00   -                 music             -                 -
#   S27                      5.00    10.00   -                 speech            -                 -
#   S28                      0.00     5.00   -                 music             -                 -
#   S28                      5.00    10.00   -                 speech            -                 -
#   S29                      0.00     5.00   -                 music             -                 -
#   S29                      5.00    10.00   -                 speech            -                 -
#   S30                      0.00     5.00   -                 music             -                 -
#   S30                      5.00    10.00   -                 speech            -                 -
#   S808                     7.00    10.00   -                 speech            -                 -
#   S809                     7.00    10.00   -                 speech            -                 -
#   S810                     7.00    10.00   -                 speech            -                 -
#   S836                     1.00     4.00   -                 speech            -                 -
#   S837                     1.00     4.00   -                 speech            -                 -
#   S838                     1.00     4.00   -                 speech            -                 -
#   S839                     1.00     4.00   -                 speech            -                 -
#   S840                     1.00     4.00   -                 speech            -                 -
#   S866                     5.00    10.00   -                 speech            -                 -
#   S867                     5.00    10.00   -                 speech            -                 -
#   S868                     5.00    10.00   -                 speech            -                 -
#   S869                     5.00    10.00   -                 speech            -                 -
#   S870                     5.00    10.00   -                 speech            -                 -
#   S896                     9.00    10.00   -                 music             -                 -
#   S897                     9.00    10.00   -                 music             -                 -
#   S898                     9.00    10.00   -                 music             -                 -
#   S899                     9.00    10.00   -                 music             -                 -
#   S900                     9.00    10.00   -                 music             -                 -
#   S926                     1.00     2.00   -                 music             -                 -
#   S927                     1.00     2.00   -                 music             -                 -
#   S928                     1.00     2.00   -                 music             -                 -
#   S929                     1.00     2.00   -                 music             -                 -
#   S930                     1.00     2.00   -                 music             -                 -
#   S956                     7.00    10.00   -                 music             -                 -
#   S957                     7.00    10.00   -                 music             -                 -
#   S958                     7.00    10.00   -                 music             -                 -
#   S959                     7.00    10.00   -                 music             -                 -
#   S960                     7.00    10.00   -                 music             -                 -
#   S986                     1.00     4.00   -                 music             -                 -
#   S987                     1.00     4.00   -                 music             -                 -
#   S988                     1.00     4.00   -                 music             -                 -
#   S989                     1.00     4.00   -                 music             -                 -
#   S990                     1.00     4.00   -                 music             -                 -
#   S1016                    5.00    10.00   -                 music             -                 -
#   S1017                    5.00    10.00   -                 music             -                 -
#   S1018                    5.00    10.00   -                 music             -                 -
#   S1019                    5.00    10.00   -                 music             -                 -
#   S1020                    5.00    10.00   -                 music             -                 -
#
# Event statistics
#   Event label             Count   Tot. Length   Avg. Length
#   --------------------   ------   -----------   -----------
#   music                     170        475.00          2.79
#   speech                    190        525.00          2.76

# %%
reference_event_list = validation_data
estimated_event_list = dcase_util.containers.MetaDataContainer(
    filename=os.path.join('/content/', 'validation_results.csv')
).load()

for item_id, item in enumerate(estimated_event_list):
    estimated_event_list[item_id]['filename'] = item.filename.split('.')[0]

# %%
print(estimated_event_list)
# Out:
# MetaDataContainer :: Class
# Filename                            : /content/validation_results.csv
# Items                               : 403
# Unique
#   Files                             : 170
#   Scene labels                      : 0
#   Event labels                      : 2
#   Tags                              : 0
#   Identifiers                       : 0
#   Source labels                     : 0
#
# Meta data
#   Source                  Onset   Offset   Scene             Event             Tags              Identifier
#   --------------------   ------   ------   ---------------   ---------------   ---------------   -----
#   S1016                    5.02     7.09   -                 music             -                 -
#   S1016                    7.64     8.37   -                 music             -                 -
#   S1016                    9.01    10.00   -                 music             -                 -
#   S1016                    7.09     9.58   -                 speech            -                 -
#   S1017                    5.37     8.79   -                 music             -                 -
#   S1017                    5.02     6.68   -                 speech            -                 -
#   S1017                    8.79     9.97   -                 speech            -                 -
#   S899                     8.98    10.00   -                 music             -                 -
#   S90                      0.00     3.99   -                 music             -                 -
#   S90                      4.98     9.97   -                 speech            -                 -
#   S900                     9.01    10.00   -                 music             -                 -
#   S926                     0.00     2.01   -                 music             -                 -
#   S927                     0.00     2.01   -                 music             -                 -
#   S927                     0.06     0.83   -                 speech            -                 -
#   S928                     0.00     2.01   -                 music             -                 -
#   S929                     0.00     2.01   -                 music             -                 -
#   S929                     0.13     0.99   -                 speech            -                 -
#   S930                     0.00     1.98   -                 music             -                 -
#   S956                     7.03    10.00   -                 music             -                 -
#   S957                     7.00    10.00   -                 music             -                 -
#   S958                     7.00    10.00   -                 music             -                 -
#   S959                     7.00    10.00   -                 music             -                 -
#   S960                     7.00    10.00   -                 music             -                 -
#   S986                     0.00     4.03   -                 music             -                 -
#   S987                     0.00     3.99   -                 music             -                 -
#   S988                     0.00     3.99   -                 music             -                 -
#   S989                     0.00     4.03   -                 music             -                 -
#   S989                     1.92     2.65   -                 speech            -                 -
#   S990                     0.00     4.03   -                 music             -                 -
#
# Event statistics
#   Event label             Count   Tot. Length   Avg. Length
#   --------------------   ------   -----------   -----------
#   music                     190        501.08          2.64
#   speech                    213        586.83          2.76

# %%
print(reference_event_list)
# Out:
# MetaDataContainer :: Class
# Items                               : 360
# Unique
#   Files                             : 170
#   Scene labels                      : 0
#   Event labels                      : 2
#   Tags                              : 0
#   Identifiers                       : 0
#   Source labels                     : 0
#
# Meta data
#   Source                  Onset   Offset   Scene             Event             Tags              Identifier
#   --------------------   ------   ------   ---------------   ---------------   ---------------   -----
#   S26                      0.00     5.00   -                 music             -                 -
#   S26                      5.00    10.00   -                 speech            -                 -
#   S27                      0.00     5.00   -                 music             -                 -
#   S27                      5.00    10.00   -                 speech            -                 -
#   S28                      0.00     5.00   -                 music             -                 -
#   S28                      5.00    10.00   -                 speech            -                 -
#   S29                      0.00     5.00   -                 music             -                 -
#   S29                      5.00    10.00   -                 speech            -                 -
#   S30                      0.00     5.00   -                 music             -                 -
#   S30                      5.00    10.00   -                 speech            -                 -
#   S56                      0.00     5.00   -                 music             -                 -
#   S56                      6.00    10.00   -                 speech            -                 -
#   S57                      0.00     5.00   -                 music             -                 -
#   S57                      6.00    10.00   -                 speech            -                 -
#   S58                      0.00     5.00   -                 music             -                 -
#   S58                      6.00    10.00   -                 speech            -                 -
#   S59                      0.00     5.00   -                 music             -                 -
#   S59                      6.00    10.00   -                 speech            -                 -
#   S60                      0.00     5.00   -                 music             -                 -
#   S60                      6.00    10.00   -                 speech            -                 -
#   S86                      0.00     4.00   -                 music             -                 -
#   S86                      5.00    10.00   -                 speech            -                 -
#   S87                      0.00     4.00   -                 music             -                 -
#   S87                      5.00    10.00   -                 speech            -                 -
#   S88                      0.00     4.00   -                 music             -                 -
#   S88                      5.00    10.00   -                 speech            -                 -
#   S89                      0.00     4.00   -                 music             -                 -
#   S89                      5.00    10.00   -                 speech            -                 -
#   S90                      0.00     4.00   -                 music             -                 -
#   S90                      5.00    10.00   -                 speech            -                 -
#   S928                     1.00     2.00   -                 music             -                 -
#   S929                     1.00     2.00   -                 music             -                 -
#   S930                     1.00     2.00   -                 music             -                 -
#   S956                     7.00    10.00   -                 music             -                 -
#   S957                     7.00    10.00   -                 music             -                 -
#   S958                     7.00    10.00   -                 music             -                 -
#   S959                     7.00    10.00   -                 music             -                 -
#   S960                     7.00    10.00   -                 music             -                 -
#   S986                     1.00     4.00   -                 music             -                 -
#   S987                     1.00     4.00   -                 music             -                 -
#   S988                     1.00     4.00   -                 music             -                 -
#   S989                     1.00     4.00   -                 music             -                 -
#   S990                     1.00     4.00   -                 music             -                 -
#   S1016                    5.00    10.00   -                 music             -                 -
#   S1017                    5.00    10.00   -                 music             -                 -
#   S1018                    5.00    10.00   -                 music             -                 -
#   S1019                    5.00    10.00   -                 music             -                 -
#   S1020                    5.00    10.00   -                 music             -                 -
#
# Event statistics
#   Event label             Count   Tot. Length   Avg. Length
#   --------------------   ------   -----------   -----------
#   music                     170        475.00          2.79
#   speech                    190        525.00          2.76

# %%
# Initialize evaluator with list of event labels to be evaluated and segment length
evaluator = sed_eval.sound_event.SegmentBasedMetrics(
    event_label_list=['speech', 'music'], 
    time_resolution=0.2                    # 1 second segments
)
# Loop file by file and accumulate intermediate statistics
for filename in reference_event_list.unique_files:
    evaluator.evaluate(
        reference_event_list=reference_event_list.filter(filename=filename),
        estimated_event_list=estimated_event_list.filter(filename=filename)
    ) 
metrics = evaluator.results_overall_metrics()

# %% [markdown]
# ## Metric values

# %%
log.table(
    column_headers=['Metric', 'Value'],
    cell_data=[
        [
          '<strong>F-score</strong>',
          'Precision',
          'Recall',
          '<strong>Error rate</strong>',
            'Substitutions',
            'Deletions',
            'Insertions'
        ],
        [
            metrics['f_measure']['f_measure']*100.0,
            metrics['f_measure']['precision']*100.0,
            metrics['f_measure']['recall']*100.0,
            metrics['error_rate']['error_rate'],
            metrics['error_rate']['substitution_rate'],
            metrics['error_rate']['deletion_rate'],
            metrics['error_rate']['insertion_rate'],
        ]
    ],
    row_separators=[3],
    scaling=130
)
# Out:
# <table class="table table-striped table-condensed" style="font-size:130%;width:auto;margin-top:0em;margin-left:0px;"><thead style="border-bottom: 0px solid transparent;"><tr><th style="width:200px;border-bottom:2px solid #333;text-align:left;">Metric</th><th style="width:60px;border-bottom:2px solid #333;text-align:right;">Value</th></tr></thead><tbody><tr><td style="text-align:left;"><strong>F-score</strong></td><td style="text-align:right;"> 90.74</td></tr><tr><td style="text-align:left;">Precision</td><td style="text-align:right;"> 84.77</td></tr><tr><td style="text-align:left;">Recall</td><td style="text-align:right;"> 97.62</td></tr><tr><td style="border-top:2px solid #333;text-align:left;"><strong>Error rate</strong></td><td style="border-top:2px solid #333;text-align:right;">  0.18</td></tr><tr><td style="text-align:left;">Substitutions</td><td style="text-align:right;">  0.02</td></tr><tr><td style="text-align:left;">Deletions</td><td style="text-align:right;">  0.00</td></tr><tr><td style="text-align:left;">Insertions</td><td style="text-align:right;">  0.15</td></tr></tbody></table>

# %% [markdown]
# ## Class-wise metrics

# %%
class_metrics = evaluator.results_class_wise_metrics()
Nref = []
Nsys = []
Fscore=[]
for event_label in list(class_metrics.keys()):
    Nref.append(class_metrics[event_label]['count']['Nref'])
    Nsys.append(class_metrics[event_label]['count']['Nsys'])
    Fscore.append(class_metrics[event_label]['f_measure']['f_measure']*100.0)
log.table(
    column_headers=['Event', 'Nref', 'Nsys', 'Fscore'],
    cell_data=[
        list(class_metrics.keys()),Nref,Nsys,Fscore
    ],
    column_types=['str25', 'int', 'int', 'float2'],
    column_separators=[0,2],
    scaling=130
)
# Out:
# <table class="table table-striped table-condensed" style="font-size:130%;width:auto;margin-top:0em;margin-left:0px;"><thead style="border-bottom: 0px solid transparent;"><tr><th style="width:250px;border-bottom:2px solid #333;border-right:2px solid #333;text-align:left;">Event</th><th style="width:60px;border-bottom:2px solid #333;text-align:right;">Nref</th><th style="width:60px;border-bottom:2px solid #333;border-right:2px solid #333;text-align:right;">Nsys</th><th style="width:60px;border-bottom:2px solid #333;text-align:right;">Fscore</th></tr></thead><tbody><tr><td style="border-right:2px solid #333;text-align:left;">speech</td><td style="text-align:right;">2625</td><td style="border-right:2px solid #333;text-align:right;">3132</td><td style="text-align:right;"> 90.74</td></tr><tr><td style="border-right:2px solid #333;text-align:left;">music</td><td style="text-align:right;">2375</td><td style="border-right:2px solid #333;text-align:right;">2626</td><td style="text-align:right;"> 90.74</td></tr></tbody></table>

# %% [markdown]
# Output directly from `sed_eval` evaluator:

# %%
print(evaluator)
# Out:
# Segment based metrics
# ========================================
#   Evaluated length                  : 1540.55 sec
#   Evaluated files                   : 170
#   Segment length                    : 200.00 ms
#
#   Overall metrics (micro-average)
#   ======================================
#   F-measure
#     F-measure (F1)                  : 90.74 %
#     Precision                       : 84.77 %
#     Recall                          : 97.62 %
#   Error rate
#     Error rate (ER)                 : 0.18
#     Substitution rate               : 0.02
#     Deletion rate                   : 0.00
#     Insertion rate                  : 0.15
#   Accuracy
#     Sensitivity                     : 97.62 %
#     Specificity                     : 91.60 %
#     Balanced accuracy               : 94.61 %
#     Accuracy                        : 93.55 %
#
#   Class-wise average metrics (macro-average)
#   ======================================
#   F-measure
#     F-measure (F1)                  : 90.74 %
#     Precision                       : 84.90 %
#     Recall                          : 97.52 %
#   Error rate
#     Error rate (ER)                 : 0.20
#     Deletion rate                   : 0.02
#     Insertion rate                  : 0.17
#   Accuracy
#     Sensitivity                     : 97.52 %
#     Specificity                     : 91.56 %
#     Balanced accuracy               : 94.54 %
#     Accuracy                        : 93.55 %
#
#
#   Class-wise metrics
#   ======================================
#     Event label  | Nref    Nsys  | F        Pre      Rec    | ER       Del      Ins    | Sens     Spec     Bacc     Acc
#     ------------ | -----   ----- | ------   ------   ------ | ------   ------   ------ | ------   ------   ------   ------
#     speech       | 2625    3132  | 90.7%    83.4%    99.5%  | 0.20     0.00     0.20   | 99.5%    89.8%    94.7%    93.1%
#     music        | 2375    2626  | 90.7%    86.4%    95.5%  | 0.19     0.04     0.15   | 95.5%    93.3%    94.4%    94.0%
